# %% [markdown]
# <a href="https://colab.research.google.com/github/u9828057/Python_Practice/blob/main/Matplotlib/Python_%E6%9A%91%E5%81%87%E7%B7%B4%E7%BF%92_08_16%3A%E3%80%90Matplotlib%E3%80%91%E7%B0%A1%E4%BB%8B%E3%80%81%E5%AE%89%E8%A3%9D%E3%80%81%E5%BF%AB%E9%80%9F%E9%96%8B%E5%A7%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("--------(Matplotlib: 簡介、安裝、快速開始)--------\n")

# 載入 Matplotlib
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [2, 4, 6])
plt.show()

plt.plot([1, 2, 3], [2, 4, 4])
plt.show()



#======================
# Matplotlib 簡介
#======================

# Matplotlib 是什麼?
# Python 的一個第三方套件
# 資料視覺化工具: 折線圖、長條圖、散布圖、圓餅圖、K線圖(蠟燭圖)、等高線圖 等

#-------------------------------------------------------------

# 安裝 Matplotlib

# 使用 pip 或 conda 安裝套件
# Windows
# pip install matplotlib
# Mac
# pip3 install matplotlib
# Conda
# conda install -c conda-forge matplotlib

#-------------------------------------------------------------

# Matplotlib 快速開始

# 使用 pyplot 模組繪製折線圖
# 載入 pyplot 模組
# 使用 plot 函式，建立折線圖所需要的資料
# 使用 show 函式，顯示出來
# Out:
# --------(Matplotlib: 簡介、安裝、快速開始)--------
